# %%
import pandas as pd
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
import os
import ast

import seaborn as sns

from api_handling import api_handling
# from Song_Consolidation import Song_Consolidation

# %%
data = api_handling(save_location='../Data/')
data.csv_pull(overwrite=True)

# %%
fsd = data.frames['full_song_data']

# %%
pd.options.display.float_format = '{:,.2f}'.format
fsd.duration_ms_x.describe()/1000 / 60
# Out:
# count    0.11
# mean     4.89
# std      2.06
# min      0.42
# 25%      3.48
# 50%      4.52
# 75%      6.30
# max     56.00
# Name: duration_ms_x, dtype: float64

# %%
fsd.columns
# Out:
# Index(['artists', 'available_markets', 'disc_number', 'duration_ms_x',
#        'explicit', 'is_local', 'name', 'popularity', 'track_number', 'uri_x',
#        'Unnamed: 0', 'meta', 'track', 'bars', 'beats', 'sections', 'segments',
#        'tatums', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'uri_y', 'track_href', 'analysis_url',
#        'duration_ms_y', 'time_signature'],
#       dtype='object')

# %%
sns.histplot(fsd.duration_ms_x/1000/60)
# Out:
# <AxesSubplot: xlabel='duration_ms_x', ylabel='Count'>

# %%
sns.histplot(fsd.valence)
# happiness basically
# Out:
# <AxesSubplot: xlabel='valence', ylabel='Count'>

# %%
sns.histplot(fsd.acousticness)
# Out:
# <AxesSubplot: xlabel='acousticness', ylabel='Count'>

# %%
sns.histplot(fsd.tempo)
# Out:
# <AxesSubplot: xlabel='tempo', ylabel='Count'>

# %%
sns.histplot(fsd.key)
# Out:
# <AxesSubplot: xlabel='key', ylabel='Count'>

# %%
sns.histplot(fsd.speechiness)
# Out:
# <AxesSubplot: xlabel='speechiness', ylabel='Count'>

# %%
sns.histplot(fsd.danceability)
# Out:
# <AxesSubplot: xlabel='danceability', ylabel='Count'>

# %%
sns.histplot(fsd.energy)
# Out:
# <AxesSubplot: xlabel='energy', ylabel='Count'>

# %%
sns.histplot(fsd.loudness)
# Out:
# <AxesSubplot: xlabel='loudness', ylabel='Count'>

# %%
sns.histplot(fsd.popularity)
# Out:
# <AxesSubplot: xlabel='popularity', ylabel='Count'>

# %%
sns.histplot(fsd.liveness)
# Out:
# <AxesSubplot: xlabel='liveness', ylabel='Count'>
